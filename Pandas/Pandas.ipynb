# %%
import numpy as np
import pandas as pd

# %%
dict1={
    "name":['Rishi','Ayan', 'Soumitra'],
    "marks":['13','55','81'],
    "city":['kolkata','mankar','burdwan']
}

# %%
df=pd.DataFrame(dict1)

# %%
df
# Out:
#        name marks     city
# 0     Rishi    13  kolkata
# 1      Ayan    55   mankar
# 2  Soumitra    81  burdwan

# %%
df.to_csv('friends.csv')

# %%
df.to_csv('friends_index_false.csv', index=False)

# %%
df.head(2)
# Out:
#     name marks     city
# 0  Rishi    13  kolkata
# 1   Ayan    55   mankar

# %%
df.tail(2)
# Out:
#        name marks     city
# 1      Ayan    55   mankar
# 2  Soumitra    81  burdwan

# %%
df.describe()
# Out:
#          name marks     city
# count       3     3        3
# unique      3     3        3
# top     Rishi    13  kolkata
# freq        1     1        1

# %%
rishi=pd.read_csv('Rishi.csv')

# %%
rishi
# Out:
#    Unnamed: 0.1  Unnamed: 0  Train No  Speed     city
# 0             0           0      1654    345  kolkata
# 1             1           1      6874    155   mankar
# 2             2           2      2654    181  burdwan

# %%
rishi['Speed']
# Out:
# 0    345
# 1    155
# 2    181
# Name: Speed, dtype: int64

# %%
rishi['Speed'][0]
# Out:
# 345

# %%
rishi['Speed'][0] =345
# Out:
# C:\Users\Asus\AppData\Local\Temp\ipykernel_27940\1243107123.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   rishi['Speed'][0] =345

# %%
rishi
# Out:
#    Unnamed: 0.1  Unnamed: 0  Train No  Speed     city
# 0             0           0      1654    345  kolkata
# 1             1           1      6874    155   mankar
# 2             2           2      2654    181  burdwan

# %%
rishi.to_csv('Rishi.csv')

# %%
rishi.index=['first','second','third']

# %%
rishi
# Out:
#         Unnamed: 0.1  Unnamed: 0  Train No  Speed     city
# first              0           0      1654    345  kolkata
# second             1           1      6874    155   mankar
# third              2           2      2654    181  burdwan

# %%
ser=pd.Series(np.random.rand(34))

# %%
ser
# Out:
# 0     0.329697
# 1     0.203279
# 2     0.965424
# 3     0.123111
# 4     0.785320
# 5     0.816700
# 6     0.153564
# 7     0.321276
# 8     0.717697
# 9     0.629071
# 10    0.220002
# 11    0.528160
# 12    0.543103
# 13    0.822883
# 14    0.061918
# 15    0.737739
# 16    0.330354
# 17    0.879082
# 18    0.643890
# 19    0.006848
# 20    0.289006
# 21    0.541200
# 22    0.416572
# 23    0.358309
# 24    0.139150
# 25    0.608250
# 26    0.005962
# 27    0.381845
# 28    0.822458
# 29    0.084615
# 30    0.057953
# 31    0.618672
# 32    0.567330
# 33    0.194813
# dtype: float64

# %%
type(ser)
# Out:
# pandas.core.series.Series

# %%
newdf=pd.DataFrame(np.random.rand(334,5), index=np.arange(334))

# %%
newdf.head()
# Out:
#           0         1         2         3         4
# 0  0.176903  0.790419  0.800634  0.224999  0.405387
# 1  0.323081  0.919134  0.924163  0.830619  0.025006
# 2  0.585677  0.017785  0.282769  0.727804  0.168233
# 3  0.628799  0.008492  0.725808  0.656819  0.386358
# 4  0.113690  0.314890  0.017629  0.220113  0.307936

# %%
newdf.describe()
# Out:
#                 0           1           2           3           4
# count  334.000000  334.000000  334.000000  334.000000  334.000000
# mean     0
#
#         7         8         9    ...       324       325       326       327  \
# 0  0.713379  0.596743  0.754762  ...  0.494486   0.62177  0.218647  0.513839
# 1  0.439487  0.243828  0.066765  ...  0.354805  0.430161  0.672508  0.000251
# 2  0.160176  0.135175  0.326046  ...  0.436176  0.753625  0.770043  0.208353
# 3  0.986691  0.468406  0.204266  ...  0.739809  0.536717   0.02335  0.441194
# 4  0.786867  0.920779  0.754498  ...  0.641693  0.589504  0.083094  0.814819
#
#         328       329       330       331       332       333
# 0   0.34708  0.908916  0.820313  0.551738  0.125231  0.984296
# 1  0.980442  0.406728   0.39376  0.894719  0.490129  0.507461
# 2  0.779571  0.471649  0.542976  0.054795  0.867126  0.814473
# 3  0.581455  0.120595  0.780756  0.459383  0.991994  0.688074
# 4  0.158074  0.180245  0.484076  0.540902  0.694749  0.232718
#
# [5 rows x 334 columns]

# %%
newdf.sort_index(axis=1,ascending=False)
# Out:
#             4         3         2         1         0
# 0    0.405387  0.224999  0.800634  0.790419       0.3
# 1    0.025006  0.830619  0.924163  0.919134  0.323081
# 2    0.168233  0.727804  0.282769  0.017785  0.585677
# 3    0.386358  0.656819  0.725808  0.008492  0.628799
# 4    0.307936  0.220113  0.017629  0.314890   0.11369
# ..        ...       ...       ...       ...       ...
# 329  0.180245  0.120595  0.471649  0.406728  0.908916
# 330  0.484076  0.780756  0.542976  0.393760  0.820313
# 331  0.540902  0.459383  0.054795  0.894719  0.551738
# 332  0.694749  0.991994  0.867126  0.490129  0.125231
# 333  0.232718  0.688074  0.814473  0.507461  0.984296
#
# [334 rows x 5 columns]

# %%
newdf[0]
# Out:
# 0           0.3
# 1      0.323081
# 2      0.585677
# 3      0.628799
# 4       0.11369
#          ...
# 329    0.908916
# 330    0.820313
# 331    0.551738
# 332    0.125231
# 333    0.984296
# Name: 0, Length: 334, dtype: object

# %%
type(newdf[0])
# Out:
# pandas.core.series.Series

# %%
newdf2=newdf

# %%
newdf2[0][0]=9874

# %%
newdf
# Out:
#             0         1         2         3         4
# 0        9874  0.790419  0.800634  0.224999  0.405387
# 1    0.323081  0.919134  0.924163  0.830619  0.025006
# 2    0.585677  0.017785  0.282769  0.727804  0.168233
# 3    0.628799  0.008492  0.725808  0.656819  0.386358
# 4     0.11369  0.314890  0.017629  0.220113  0.307936
# ..        ...       ...       ...       ...       ...
# 329  0.908916  0.406728  0.471649  0.120595  0.180245
# 330  0.820313  0.393760  0.542976  0.780756  0.484076
# 331  0.551738  0.894719  0.054795  0.459383  0.540902
# 332  0.125231  0.490129  0.867126  0.991994  0.694749
# 333  0.984296  0.507461  0.814473  0.688074  0.232718
#
# [334 rows x 5 columns]

# %%
newdf2=newdf.copy()

# %%
newdf.loc[0,0]=654

# %%
newdf.head(2)
# Out:
#           0         1         2         3         4
# 0       654  0.790419  0.800634  0.224999  0.405387
# 1  0.323081  0.919134  0.924163  0.830619  0.025006

# %%
newdf.columns=list("ABCDE")

# %%
newdf
# Out:
#             A         B         C         D         E
# 0         654  0.790419  0.800634  0.224999  0.405387
# 1    0.323081  0.919134  0.924163  0.830619  0.025006
# 2    0.585677  0.017785  0.282769  0.727804  0.168233
# 3    0.628799  0.008492  0.725808  0.656819  0.386358
# 4     0.11369  0.314890  0.017629  0.220113  0.307936
# ..        ...       ...       ...       ...       ...
# 329  0.908916  0.406728  0.471649  0.120595  0.180245
# 330  0.820313  0.393760  0.542976  0.780756  0.484076
# 331  0.551738  0.894719  0.054795  0.459383  0.540902
# 332  0.125231  0.490129  0.867126  0.991994  0.694749
# 333  0.984296  0.507461  0.814473  0.688074  0.232718
#
# [334 rows x 5 columns]

# %%
newdf.drop(0)
# Out:
#             A         B         C         D         E
# 1    0.323081  0.919134  0.924163  0.830619  0.025006
# 2    0.585677  0.017785  0.282769  0.727804  0.168233
# 3    0.628799  0.008492  0.725808  0.656819  0.386358
# 4     0.11369  0.314890  0.017629  0.220113  0.307936
# 5    0.442547  0.362646  0.866194  0.871696  0.961525
# ..        ...       ...       ...       ...       ...
# 329  0.908916  0.406728  0.471649  0.120595  0.180245
# 330  0.820313  0.393760  0.542976  0.780756  0.484076
# 331  0.551738  0.894719  0.054795  0.459383  0.540902
# 332  0.125231  0.490129  0.867126  0.991994  0.694749
# 333  0.984296  0.507461  0.814473  0.688074  0.232718
#
# [333 rows x 5 columns]

# %%
newdf.loc[0,0]=665

# %%
newdf.head()
# Out:
#           A         B         C         D         E      0
# 0       654  0.790419  0.800634  0.224999  0.405387  665.0
# 1  0.323081  0.919134  0.924163  0.830619  0.025006    NaN
# 2  0.585677  0.017785  0.282769  0.727804  0.168233    NaN
# 3  0.628799  0.008492  0.725808  0.656819  0.386358    NaN
# 4   0.11369  0.314890  0.017629  0.220113  0.307936    NaN

# %%
newdf.drop(0, axis=1)
# Out:
#             A         B         C         D         E
# 0         654  0.790419  0.800634  0.224999  0.405387
# 1    0.323081  0.919134  0.924163  0.830619  0.025006
# 2    0.585677  0.017785  0.282769  0.727804  0.168233
# 3    0.628799  0.008492  0.725808  0.656819  0.386358
# 4     0.11369  0.314890  0.017629  0.220113  0.307936
# ..        ...       ...       ...       ...       ...
# 329  0.908916  0.406728  0.471649  0.120595  0.180245
# 330  0.820313  0.393760  0.542976  0.780756  0.484076
# 331  0.551738  0.894719  0.054795  0.459383  0.540902
# 332  0.125231  0.490129  0.867126  0.991994  0.694749
# 333  0.984296  0.507461  0.814473  0.688074  0.232718
#
# [334 rows x 5 columns]

# %%
newdf.loc[[1,2] , ["C","D"]]
# Out:
#           C         D
# 1  0.924163  0.830619
# 2  0.282769  0.727804

# %%
newdf.loc[[1,2],:]
# Out:
#           A         B         C         D         E   0
# 1  0.323081  0.919134  0.924163  0.830619  0.025006 NaN
# 2  0.585677  0.017785  0.282769  0.727804  0.168233 NaN
